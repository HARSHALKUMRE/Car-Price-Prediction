# %%
from pymongo import MongoClient
import pandas as pd
from json import loads
import os

# %%
data_frame = pd.read_csv(r'data/cardekho_dataset.csv')

# %%
data_frame.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# ...

# %%
data_frame.columns
# Out:
# Index(['Unnamed: 0', 'car_name', 'brand', 'model', 'vehicle_age', 'km_driven',
#        'seller_type', 'fuel_type', 'transmission_type', 'mileage', 'engine',
#        'max_power', 'seats', 'selling_price'],
#       dtype='object')

# %%
data_frame.drop(columns=['Unnamed: 0'], axis=1, inplace=True)

# %%
data_frame.head()
# Out:
#         car_name    brand     model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti      Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai     Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai       i20           11      60000  Individual
# 3    Maruti Alto   Maruti      Alto            9      37000  Individual
# 4  Ford Ecosport     Ford  Ecosport            6      30000      Dealer
#
#   fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0    Petrol            Manual    19.70     796      46.30      5
# 1    Petrol            Manual    18.90    1197      82.00      5
# 2    Petrol            Manual    17.00    1197      80.00      5
# 3    Petrol            Manual    20.92     998      67.10      5
# 4    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %%
records = list(loads(data_frame.T.to_json()).values())

# %%
from dotenv import load_dotenv
print(f"Reading Environment Variables")
load_dotenv()
# Out:
# Reading Environment Variables
# True

# %%
import urllib

# %%
client = MongoClient(os.getenv('MONGODB_URL'))

# %%
database_name = client["iNeuron"]
database_name
# Out:
# Database(MongoClient(host=['ac-n0c4hld-shard-00-01.pcq2e8v.mongodb.net:27017', 'ac-n0c4hld-shard-00-02.pcq2e8v.mongodb.net:27017', 'ac-n0c4hld-shard-00-00.pcq2e8v.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-4euknf-shard-0', tls=True), 'iNeuron')

# %%
collection = database_name["car"]
collection
# Out:
# Collection(Database(MongoClient(host=['ac-n0c4hld-shard-00-01.pcq2e8v.mongodb.net:27017', 'ac-n0c4hld-shard-00-02.pcq2e8v.mongodb.net:27017', 'ac-n0c4hld-shard-00-00.pcq2e8v.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-4euknf-shard-0', tls=True), 'iNeuron'), 'car')

# %%
collection.insert_many(records)
# Out:
# InsertManyResult([ObjectId('66179afb8faf49c67a0671e5'), ObjectId('66179afb8faf49c67a0671e6'), ObjectId('66179afb8faf49c67a0671e7'), ObjectId('66179afb8faf49c67a0671e8'), ObjectId('66179afb8faf49c67a0671e9'), ObjectId('66179afb8faf49c67a0671ea'), ObjectId('66179afb8faf49c67a0671eb'), ObjectId('66179afb8faf49c67a0671ec'), ObjectId('66179afb8faf49c67a0671ed'), ObjectId('66179afb8faf49c67a0671ee'), ObjectId('66179afb8faf49c67a0671ef'), ObjectId('66179afb8faf49c67a0671f0'), ObjectId('66179afb8faf49c67a0671f1'), ObjectId('66179afb8faf49c67a0671f2'), ObjectId('66179afb8faf49c67a0671f3'), ObjectId('66179afb8faf49c67a0671f4'), ObjectId('66179afb8faf49c67a0671f5'), ObjectId('66179afb8faf49c67a0671f6'), ObjectId('66179afb8faf49c67a0671f7'), ObjectId('66179afb8faf49c67a0671f8'), ObjectId('66179afb8faf49c67a0671f9'), ObjectId('66179afb8faf49c67a0671fa'), ObjectId('66179afb8faf49c67a0671fb'), ObjectId('66179afb8faf49c67a0671fc'), ObjectId('66179afb8faf49c67a0671fd'), ObjectId('66179afb8faf49c67a06
# ...
